# %%
# dependency tree
# reference: https://www.analyticsvidhya.com/blog/2017/12/introduction-computational-linguistics-dependency-trees/?utm_source=feedburner&utm_medium=email&utm_campaign=Feed%3A+AnalyticsVidhya+%28Analytics+Vidhya%29

s1 = "Baby Emmanuel saw a Totoro with a camera."
s2 = "Baby Emmaunel saw a Totoro in his pajama."

# %%
import spacy

nlp = spacy.load("en")

d1 = nlp(s1.decode('utf-8'))
d2 = nlp(s2.decode('utf-8'))

for token in d1:
    print str(token.text),  str(token.lemma_),  str(token.pos_),  str(token.dep_)

print "**********************"
    
for token in d2:
    print str(token.text),  str(token.lemma_),  str(token.pos_),  str(token.dep_)
# Out:
# Baby baby PROPN compound
# Emmanuel emmanuel PROPN nsubj
# saw see VERB ROOT
# a a DET det
# Totoro totoro PROPN dobj
# with with ADP prep
# a a DET det
# camera camera NOUN pobj
# . . PUNCT punct
# **********************
# Baby baby PROPN nsubj
# saw see VERB ROOT
# a a DET det
# Totoro totoro PROPN dobj
# in in ADP prep
# his -PRON- ADJ poss
# pajama pajama NOUN pobj
# . . PUNCT punct

# %%
from spacy import displacy
from IPython.display import HTML

displacy.render(d1, style='dep', jupyter=True, options={'distance':107})
# displacy params: https://github.com/explosion/spaCy/issues/1058

# hide Ipython warnings
HTML('''<script>
code_show_err=false; 
function code_toggle_err() {
 $('div.output_stderr').hide()
} 
$( document ).ready(code_toggle_err);
</script>''')
# Out:
# /Users/hanhanwu/anaconda/lib/python2.7/runpy.py:174: DeprecationWarning: Positional arguments to Doc.merge are deprecated. Instead, use the keyword arguments, for example tag=, lemma= or ent_type=.
#   "__main__", fname, loader, pkg_name)
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="906" height="296" style="max-width: none; height: 296px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="206">
#     <tspan class="displacy-word" fill="currentColor" x="50">Baby</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="206">
#     <tspan class="displacy-word" fill="currentColor" x="157">Emmanuel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="157">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="206">
#     <tspan class="displacy-word" fill="currentColor" x="264">saw</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="264">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="206">
#     <tspan class="displacy-word" fill="currentColor" x="371">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="371">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="206">
#     <tspan class="displacy-word" fill="currentColor" x="478">Totoro</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="478">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="206">
#     <tspan class="displacy-word" fill="currentColor" x="585">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="585">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="206">
#     <tspan class="displacy-word" fill="currentColor" x="692">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="692">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="206">
#     <tspan class="displacy-word" fill="currentColor" x="799">camera.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="799">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,161 C70,108 147,108 147,161" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M147,163 L155,151 139,151" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M177,161 C177,108 254,108 254,161" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M254,163 L262,151 246,151" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M391,161 C391,108 468,108 468,161" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M468,163 L476,151 460,151" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M284,161 C284,54 473,54 473,161" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M473,163 L481,151 465,151" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M284,161 C284,1 585,1 585,161" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M585,163 L593,151 577,151" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-5" stroke-width="2px" d="M712,161 C712,108 789,108 789,161" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-5" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M789,163 L797,151 781,151" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-6" stroke-width="2px" d="M605,161 C605,54 794,54 794,161" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-6" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M794,163 L802,151 786,151" fill="currentColor"/>
# </g>
# </svg>
# <script>
# code_show_err=false;
# function code_toggle_err() {
#  $('div.output_stderr').hide()
# }
# $( document ).ready(code_toggle_err);
# </script>

# %%
## Stanford CORE NLP METHOD 1 - pycorenlp

# To turn on the server first
# cd stanford-corenlp-full-2017-06-09/
# java -mx5g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -timeout 10000

from pycorenlp import StanfordCoreNLP
nlp = StanfordCoreNLP('http://127.0.0.1:9000')
res = nlp.annotate(s1,
                   properties={
                       'annotators': 'parse',
                       'outputFormat': 'json',
                       'timeout': 1000,
                   })
res
# Out:
# {u'sentences': [{u'basicDependencies': [{u'dep': u'ROOT',
#      u'dependent': 3,
#      u'dependentGloss': u'saw',
#      u'governor': 0,
#      u'governorGloss': u'ROOT'},
#     {u'dep': u'compound',
#      u'dependent': 1,
#      u'dependentGloss': u'Baby',
#      u'governor': 2,
#      u'governorGloss': u'Emmanuel'},
#     {u'dep': u'nsubj',
#      u'dependent': 2,
#      u'dependentGloss': u'Emmanuel',
#      u'governor': 3,
#      u'governorGloss': u'saw'},
#     {u'dep': u'det',
#      u'dependent': 4,
#      u'dependentGloss': u'a',
#      u'governor': 5,
#      u'governorGloss': u'Totoro'},
#     {u'dep': u'dobj',
#      u'dependent': 5,
#      u'dependentGloss': u'Totoro',
#      u'governor': 3,
#      u'governorGloss': u'saw'},
#     {u'dep': u'case',
#      u'dependent': 6,
#      u'dependentGloss': u'with',
#      u'governor': 8,
#      u'governorGloss': u'camera'},
#     {u'dep': u'det',
#      u'dependent': 7,
#      u'dependentGloss': u'a',
#      u'governor': 8,
#      u'governorGloss': u'camera'},
#     {u'dep': u'nmod',
#      u'dependent': 8,
#      u'dependentGloss': u'camera',
#      u'governor': 3,
#      u'governorGloss': u'saw'},
#     {u'dep': u'punct',
#      u'dependent': 9,
#      u'dependentGloss': u'.',
#      u'governor': 3,
#      u'governorGloss': u'saw'}],
#    u'enhancedDependencies': [{u'dep': u'ROOT',
#      u'dependent': 3,
#      u'dependentGloss': u'saw',
#      u'governor': 0,
#      u'governorGloss': u'ROOT'},
#     {u'dep': u'compound',
#      u'dependent': 1,
#      u'dependentGloss': u'Baby',
#      u'governor': 2,
#      u'governorGloss': u'Emmanuel'},
#     {u'dep': u'nsubj',
#      u'dependent': 2,
#      u'dependentGloss': u'Emmanuel',
#      u'governor': 3,
#      u'governorGloss': u'saw'},
#     {u'dep': u'det',
#      u'dependent': 4,
#      u'dependentGloss': u'a',
#      u'governor': 5,
#      u'governorGloss': u'Totoro'},
#     {u'dep': u'dobj',
#      u'dependent': 5,
#      u'dependentGloss': u'Totoro',
#      u'governor': 3,
#      u'governorGloss': u'saw'},
#     {u'dep': u'case',
#      u'dependent': 6,
#      u'dependentGloss': u'with',
#      u'governor': 8,
#      u'governorGloss': u'camera'},
#     {u'dep': u'det',
#      u'dependent': 7,
#      u'dependentGloss': u'a',
#      u'governor': 8,
#      u'governorGloss': u'camera'},
#     {u'dep': u'nmod:with',
#      u'dependent': 8,
#      u'dependentGloss': u'camera',
#      u'governor': 3,
#      u'governorGloss': u'saw'},
#     {u'dep': u'punct',
#      u'dependent': 9,
#      u'dependentGloss': u'.',
#      u'governor': 3,
#      u'governorGloss': u'saw'}],
#    u'enhancedPlusPlusDependencies': [{u'dep': u'ROOT',
#      u'dependent': 3,
#      u'dependentGloss': u'saw',
#      u'governor': 0,
#      u'governorGloss': u'ROOT'},
#     {u'dep': u'compound',
#      u'dependent': 1,
#      u'dependentGloss': u'Baby',
#      u'governor': 2,
#      u'governorGloss': u'Emmanuel'},
#     {u'dep': u'nsubj',
#      u'dependent': 2,
#      u'dependentGloss': u'Emmanuel',
#      u'governor': 3,
#      u'governorGloss': u'saw'},
#     {u'dep': u'det',
#      u'dependent': 4,
#      u'dependentGloss': u'a',
#      u'governor': 5,
#      u'governorGloss': u'Totoro'},
#     {u'dep': u'dobj',
#      u'dependent': 5,
#      u'dependentGloss': u'Totoro',
#      u'governor': 3,
#      u'governorGloss': u'saw'},
#     {u'dep': u'case',
#      u'dependent': 6,
#      u'dependentGloss': u'with',
#      u'governor': 8,
#      u'governorGloss': u'camera'},
#     {u'dep': u'det',
#      u'dependent': 7,
#      u'dependentGloss': u'a',
#      u'governor': 8,
#      u'governorGloss': u'camera'},
#     {u'dep': u'nmod:with',
#      u'dependent': 8,
#      u'dependentGloss': u'camera',
#      u'governor': 3,
#      u'governorGloss': u'saw'},
#     {u'dep': u'punct',
#      u'dependent': 9,
#      u'dependentGloss': u'.',
#      u'governor': 3,
#      u'governorGloss': u'saw'}],
#    u'index': 0,
#    u'parse': u'(ROOT\n  (S\n    (NP (NNP Baby) (NNP Emmanuel))\n    (VP (VBD saw)\n      (NP (DT a) (NN Totoro))\n      (PP (IN with)\n        (NP (DT a) (NN camera))))\n    (. .)))',
#    u'tokens': [{u'after': u' ',
#      u'before': u'',
#      u'characterOffsetBegin': 0,
#      u'characterOffsetEnd': 4,
#      u'index': 1,
#      u'originalText': u'Baby',
#      u'pos': u'NNP',
#      u'word': u'Baby'},
#     {u'after': u' ',
#      u'before': u' ',
#      u'characterOffsetBegin': 5,
#      u'characterOffsetEnd': 13,
#      u'index': 2,
#      u'originalText': u'Emmanuel',
#      u'pos': u'NNP',
#      u'word': u'Emmanuel'},
#     {u'after': u' ',
#      u'before': u' ',
#      u'characterOffsetBegin': 14,
#      u'characterOffsetEnd': 17,
#      u'index': 3,
#      u'originalText': u'saw',
#      u'pos': u'VBD',
#      u'word': u'saw'},
#     {u'after': u' ',
#      u'before': u' ',
#      u'characterOffsetBegin': 18,
#      u'characterOffsetEnd': 19,
#      u'index': 4,
#      u'originalText': u'a',
#      u'pos': u'DT',
#      u'word': u'a'},
#     {u'after': u' ',
#      u'before': u' ',
#      u'characterOffsetBegin': 20,
#      u'characterOffsetEnd': 26,
#      u'index': 5,
#      u'originalText': u'Totoro',
#      u'pos': u'NN',
#      u'word': u'Totoro'},
#     {u'after': u' ',
#      u'before': u' ',
#      u'characterOffsetBegin': 27,
#      u'characterOffsetEnd': 31,
#      u'index': 6,
#      u'originalText': u'with',
#      u'pos': u'IN',
#      u'word': u'with'},
#     {u'after': u' ',
#      u'before': u' ',
#      u'characterOffsetBegin': 32,
#      u'characterOffsetEnd': 33,
#      u'index': 7,
#      u'originalText': u'a',
#      u'pos': u'DT',
#      u'word': u'a'},
#     {u'after': u'',
#      u'before': u' ',
#      u'characterOffsetBegin': 34,
#      u'characterOffsetEnd': 40,
#      u'index': 8,
#      u'originalText': u'camera',
#      u'pos': u'NN',
#      u'word': u'camera'},
#     {u'after': u'',
#      u'before': u'',
#      u'characterOffsetBegin': 40,
#      u'characterOffsetEnd': 41,
#      u'index': 9,
#      u'originalText': u'.',
#      u'pos': u'.',
#      u'word': u'.'}]}]}

# %%
## Stanford CORE NLP METHOD 3 - stanfordcorenlp

from stanfordcorenlp import StanfordCoreNLP

nlp = StanfordCoreNLP(r'../stanford-corenlp-full-2017-06-09/')  # pay attention to the path here

# %%
print 'Part of Speech:'
print nlp.pos_tag(s1)
# Out:
# Part of Speech:
# [(u'Baby', u'NNP'), (u'Emmanuel', u'NNP'), (u'saw', u'VBD'), (u'a', u'DT'), (u'Totoro', u'NN'), (u'with', u'IN'), (u'a', u'DT'), (u'camera', u'NN'), (u'.', u'.')]

# %%
print 'Dependency Parsing:'
print nlp.dependency_parse(s1)  # what a tree...
# Out:
# Dependency Parsing:
# [(u'ROOT', 0, 3), (u'compound', 2, 1), (u'nsubj', 3, 2), (u'det', 5, 4), (u'dobj', 3, 5), (u'case', 8, 6), (u'det', 8, 7), (u'nmod', 5, 8), (u'punct', 3, 9)]
